# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# !pip install pdpipe
import pdpipe as pdp
# %matplotlib inline
# Out:
# Requirement already satisfied: pdpipe in /usr/local/lib/python3.12/dist-packages (1.1.0)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pdpipe) (2.2.2)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.12/dist-packages (from pdpipe) (2.4.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from pdpipe) (4.67.1)
# Requirement already satisfied: strct in /usr/local/lib/python3.12/dist-packages (from pdpipe) (0.0.35)
# Requirement already satisfied: skutil>=0.0.15 in /usr/local/lib/python3.12/dist-packages (from pdpipe) (0.0.19)
# Requirement already satisfied: birch>=0.0.34 in /usr/local/lib/python3.12/dist-packages (from pdpipe) (0.0.35)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->pdpipe) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->pdpipe) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->pdpipe) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->pdpipe) (2025.2)
# Requirement already satisfied: decore in /usr/local/lib/python3.12/dist-packages (from skutil>=0.0.15->pdpipe) (0.0.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->pdpipe) (1.17.0)

# %%
import warnings
warnings.filterwarnings('ignore')


pd.options.display.max_colwidth=300

np.set_printoptions(suppress=True)
pd.options.display.float_format = '{:.2f}'.format

pd.set_option('display.max_columns', None)

df_train = pd.read_csv("social_media_train.csv",index_col=[0])
display(df_train.head(),df_train.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 576 entries, 0 to 575
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   fake                   576 non-null    int64
#  1   profile_pic            576 non-null    object
#  2   ratio_numlen_username  576 non-null    float64
#  3   len_fullname           576 non-null    int64
#  4   ratio_numlen_fullname  576 non-null    float64
#  5   sim_name_username      576 non-null    object
#  6   len_desc               576 non-null    int64
#  7   extern_url             576 non-null    object
#  8   private                576 non-null    object
#  9   num_posts              576 non-null    int64
#  10  num_followers          576 non-null    int64
#  11  num_following          576 non-null    int64
# dtypes: float64(2), int64(6), object(4)
# memory usage: 58.5+ KB
#    fake profile_pic  ratio_numlen_username  len_fullname  \
# 0     0         Yes                   0.27             0
# 1     0         Yes                   0.00             2
# 2     0         Yes                   0.10             2
# 3     0         Yes                   0.00             1
# 4     0         Yes                   0.00             2
#
#    ratio_numlen_fullname sim_name_username  len_desc extern_url private  \
# 0                   0.00          No match        53         No      No
# 1                   0.00     Partial match        44         No      No
# 2                   0.00     Partial match         0         No     Yes
# 3                   0.00     Partial match        82         No      No
# 4                   0.00          No match         0         No     Yes
#
#    num_posts  num_followers  num_following
# 0         32           1000            955
# 1        286           2740            533
# 2         13            159             98
# 3        679            414            651
# 4          6            151            126
# None

# %%
data_dict = pd.read_csv('fake_account__data_dict.csv', index_col = 'No.')
data_dict
# Out:
#                  Column name          Data Type  \
# No.
# 0              'profile_pic'        categorical
# 1    'ratio_numlen_username'  numerical (float)
# 2             'len_fullname'    numerical (int)
# 3    'ratio_numlen_fullname'  numerical (float)
# 4        'sim_name_username'        categorical
# 5                 'len_desc'    numerical (int)
# 6               'extern_url'        categorical
# 7                  'private'        categorical
# 8                'num_posts'    numerical (int)
# 9            'num_followers'    numerical (int)
# 10           'num_following'    numerical (int)
# 11                    'fake'        categorical
#
#                                                                                          Description
# No.
# 0                                           Whether the account has a profile picture (1) or not (0)
# 1                                  Ratio of numeric characters in the account username to its length
# 2                                                       Number of characters in the user's full name
# 3                                  Ratio of numeric characters in the user's full name to its length
# 4                      Whether the user's name matches their username completely (1),not at all (0).
# 5                                                    Number of characters in the account description
# 6                                      Whether the account description includes a URL (1) or not (2)
# 7    Whether the user's posts are visible only to their followers (1) or to all Instagram users (2).
# 8                                                                Number of posts in the user account
# 9                                                    Number of Instagram users following the account
# 10                                                 Number of Instagram users followed by the account
# 11                                       Whether the user account is real (0) or a fake account (1).

# %%
num_cols = ['ratio_numlen_username','len_fullname','ratio_numlen_fullname',
            'len_desc','num_posts','num_followers',
              'num_following']

cat_cols = [col for col in df_train.columns.values.tolist() if col not in num_cols]
cat_cols
# Out:
# ['fake', 'profile_pic', 'sim_name_username', 'extern_url', 'private']

# %%
df_train[num_cols].describe()
# Out:
#        ratio_numlen_username  len_fullname  ratio_numlen_fullname  len_desc  \
# count                 576.00        576.00                 576.00    576.00
# mean                    0.16          1.46                   0.04     22.62
# std                     0.21          1.05                   0.13     37.70
# min                     0.00          0.00                   0.00      0.00
# 25%                     0.00          1.00                   0.00      0.00
# 50%                     0.00          1.00                   0.00      0.00
# 75%                     0.31          2.00                   0.00     34.00
# max                     0.92         12.00                   1.00    150.00
#
#        num_posts  num_followers  num_following
# count     576.00         576.00         576.00
# mean      107.49       85307.24         508.38
# std       402.03      910148.46         917.98
# min         0.00           0.00           0.00
# 25%         0.00          39.00          57.50
# 50%         9.00         150.50         229.50
# 75%        81.50         716.00         589.50
# max      7389.00    15338538.00        7500.00

# %%
plt.figure(figsize=(15,6))
fake_share = df_train["fake"].value_counts()
mylabel=["Not fake(0)","fake(1)"]
colors = ['#99ff99','#ff9999']
plt.pie(fake_share,
        labels=mylabel,autopct="%1.1f%%",colors=colors,
        textprops={'fontsize': 16})
plt.axis("equal");

# %%
percent_missing = df_train.isnull().sum() * 100 / len(df_train)
missing_value_df = pd.DataFrame({'percent_missing (%)': percent_missing})
missing_value_df.sort_values('percent_missing (%)', ascending=False)
# Out:
#                        percent_missing (%)
# fake                                  0.00
# profile_pic                           0.00
# ratio_numlen_username                 0.00
# len_fullname                          0.00
# ratio_numlen_fullname                 0.00
# sim_name_username                     0.00
# len_desc                              0.00
# extern_url                            0.00
# private                               0.00
# num_posts                             0.00
# num_followers                         0.00
# num_following                         0.00

# %%
corr = df_train[num_cols].corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_c1697_row0_col0, #T_c1697_row1_col1, #T_c1697_row2_col2, #T_c1697_row3_col3, #T_c1697_row4_col4, #T_c1697_row5_col5, #T_c1697_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_c1697_row0_col1, #T_c1697_row0_col3, #T_c1697_row0_col4, #T_c1697_row0_col5, #T_c1697_row0_col6, #T_c1697_row3_col0, #T_c1697_row3_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_c1697_row0_col2 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_c1697_row1_col0 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_c1697_row1_col2 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_c1697_row1_col3 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_c1697_row1_col4 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_c1697_row1_col5 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_c1697_row1_col6 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_c1697_row2_col0 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_c1697_row2_col1 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_c1697_row2_col3 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_c1697_row2_col4, #T_c1697_row2_col6 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_c1697_row2_col5 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_c1697_row3_col1 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_c1697_row3_col4, #T_c1697_row6_col1 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_c1697_row3_col5 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_c1697_row3_col6 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_c1697_row4_col0 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_c1697_row4_col1 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_c1697_row4_col2 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_c1697_row4_col3 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_c1697_row4_col5 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_c1697_row4_col6 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_c1697_row5_col0 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_c1697_row5_col1 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_c1697_row5_col2 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_c1697_row5_col3 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_c1697_row5_col4 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_c1697_row5_col6 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_c1697_row6_col0 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_c1697_row6_col2 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_c1697_row6_col3 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_c1697_row6_col4 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_c1697_row6_col5 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c1697" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c1697_level0_col0" class="col_heading level0 col0" >ratio_numlen_username</th>
#       <th id="T_c1697_level0_col1" class="col_heading level0 col1" >len_fullname</th>
#       <th id="T_c1697_level0_col2" class="col_heading level0 col2" >ratio_numlen_fullname</th>
#       <th id="T_c1697_level0_col3" class="col_heading level0 col3" >len_desc</th>
#       <th id="T_c1697_level0_col4" class="col_heading level0 col4" >num_posts</th>
#       <th id="T_c1697_level0_col5" class="col_heading level0 col5" >num_followers</th>
#       <th id="T_c1697_level0_col6" class="col_heading level0 col6" >num_following</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c1697_level0_row0" class="row_heading level0 row0" >ratio_numlen_username</th>
#       <td id="T_c1697_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_c1697_row0_col1" class="data row0 col1" >-0.225472</td>
#       <td id="T_c1697_row0_col2" class="data row0 col2" >0.408567</td>
#       <td id="T_c1697_row0_col3" class="data row0 col3" >-0.321170</td>
#       <td id="T_c1697_row0_col4" class="data row0 col4" >-0.157442</td>
#       <td id="T_c1697_row0_col5" class="data row0 col5" >-0.062785</td>
#       <td id="T_c1697_row0_col6" class="data row0 col6" >-0.172413</td>
#     </tr>
#     <tr>
#       <th id="T_c1697_level0_row1" class="row_heading level0 row1" >len_fullname</th>
#       <td id="T_c1697_row1_col0" class="data row1 col0" >-0.225472</td>
#       <td id="T_c1697_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_c1697_row1_col2" class="data row1 col2" >-0.094348</td>
#       <td id="T_c1697_row1_col3" class="data row1 col3" >0.272522</td>
#       <td id="T_c1697_row1_col4" class="data row1 col4" >0.073350</td>
#       <td id="T_c1697_row1_col5" class="data row1 col5" >0.033225</td>
#       <td id="T_c1697_row1_col6" class="data row1 col6" >0.094855</td>
#     </tr>
#     <tr>
#       <th id="T_c1697_level0_row2" class="row_heading level0 row2" >ratio_numlen_fullname</th>
#       <td id="T_c1697_row2_col0" class="data row2 col0" >0.408567</td>
#       <td id="T_c1697_row2_col1" class="data row2 col1" >-0.094348</td>
#       <td id="T_c1697_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_c1697_row2_col3" class="data row2 col3" >-0.117521</td>
#       <td id="T_c1697_row2_col4" class="data row2 col4" >-0.057716</td>
#       <td id="T_c1697_row2_col5" class="data row2 col5" >-0.027035</td>
#       <td id="T_c1697_row2_col6" class="data row2 col6" >-0.067971</td>
#     </tr>
#     <tr>
#       <th id="T_c1697_level0_row3" class="row_heading level0 row3" >len_desc</th>
#       <td id="T_c1697_row3_col0" class="data row3 col0" >-0.321170</td>
#       <td id="T_c1697_row3_col1" class="data row3 col1" >0.272522</td>
#       <td id="T_c1697_row3_col2" class="data row3 col2" >-0.117521</td>
#       <td id="T_c1697_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_c1697_row3_col4" class="data row3 col4" >0.144824</td>
#       <td id="T_c1697_row3_col5" class="data row3 col5" >0.005929</td>
#       <td id="T_c1697_row3_col6" class="data row3 col6" >0.226561</td>
#     </tr>
#     <tr>
#       <th id="T_c1697_level0_row4" class="row_heading level0 row4" >num_posts</th>
#       <td id="T_c1697_row4_col0" class="data row4 col0" >-0.157442</td>
#       <td id="T_c1697_row4_col1" class="data row4 col1" >0.073350</td>
#       <td id="T_c1697_row4_col2" class="data row4 col2" >-0.057716</td>
#       <td id="T_c1697_row4_col3" class="data row4 col3" >0.144824</td>
#       <td id="T_c1697_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_c1697_row4_col5" class="data row4 col5" >0.321385</td>
#       <td id="T_c1697_row4_col6" class="data row4 col6" >0.098225</td>
#     </tr>
#     <tr>
#       <th id="T_c1697_level0_row5" class="row_heading level0 row5" >num_followers</th>
#       <td id="T_c1697_row5_col0" class="data row5 col0" >-0.062785</td>
#       <td id="T_c1697_row5_col1" class="data row5 col1" >0.033225</td>
#       <td id="T_c1697_row5_col2" class="data row5 col2" >-0.027035</td>
#       <td id="T_c1697_row5_col3" class="data row5 col3" >0.005929</td>
#       <td id="T_c1697_row5_col4" class="data row5 col4" >0.321385</td>
#       <td id="T_c1697_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_c1697_row5_col6" class="data row5 col6" >-0.011066</td>
#     </tr>
#     <tr>
#       <th id="T_c1697_level0_row6" class="row_heading level0 row6" >num_following</th>
#       <td id="T_c1697_row6_col0" class="data row6 col0" >-0.172413</td>
#       <td id="T_c1697_row6_col1" class="data row6 col1" >0.094855</td>
#       <td id="T_c1697_row6_col2" class="data row6 col2" >-0.067971</td>
#       <td id="T_c1697_row6_col3" class="data row6 col3" >0.226561</td>
#       <td id="T_c1697_row6_col4" class="data row6 col4" >0.098225</td>
#       <td id="T_c1697_row6_col5" class="data row6 col5" >-0.011066</td>
#       <td id="T_c1697_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
pp_cols = []
pp_cols = num_cols + ['fake']
ax=sns.pairplot(df_train[pp_cols], hue="fake",corner=True);
plt.style.use('fivethirtyeight')
ax.fig.suptitle("Pair Plot of Characteristics")
# Out:
# Text(0.5, 0.98, 'Pair Plot of Characteristics')

# %%
display(df_train.loc[:, cat_cols].head())

for col in cat_cols:
    unique_values = df_train.loc[:, col].unique()
    print("\nColumn name: {}\nUnique values: {}".format(col, unique_values))
# Out:
#    fake profile_pic sim_name_username extern_url private
# 0     0         Yes          No match         No      No
# 1     0         Yes     Partial match         No      No
# 2     0         Yes     Partial match         No     Yes
# 3     0         Yes     Partial match         No      No
# 4     0         Yes          No match         No     Yes
# Column name: fake
# Unique values: [0 1]
#
# Column name: profile_pic
# Unique values: ['Yes' 'No']
#
# Column name: sim_name_username
# Unique values: ['No match' 'Partial match' 'Full match']
#
# Column name: extern_url
# Unique values: ['No' 'Yes']
#
# Column name: private
# Unique values: ['No' 'Yes']

# %%
def label_encoding(df):
    dict_label_encoding = {'Yes': 1, 'No': 0}
    df.loc[:, 'profile_pic'] = df.loc[:, 'profile_pic'].replace(dict_label_encoding)
    df.loc[:, 'extern_url'] = df.loc[:, 'extern_url'].replace(dict_label_encoding)
    df.loc[:, 'private'] = df.loc[:, 'private'].replace(dict_label_encoding)

    onehot = pdp.OneHotEncode(["sim_name_username"], drop_first=False)
    df = onehot.fit_transform(df)
    return df

df_train = label_encoding(df_train)
df_train.head()
# Out:
#    fake profile_pic  ratio_numlen_username  len_fullname  \
# 0     0           1                   0.27             0
# 1     0           1                   0.00             2
# 2     0           1                   0.10             2
# 3     0           1                   0.00             1
# 4     0           1                   0.00             2
#
#    ratio_numlen_fullname  len_desc extern_url private  num_posts  \
# 0                   0.00        53          0       0         32
# 1                   0.00        44          0       0        286
# 2                   0.00         0          0       1         13
# 3                   0.00        82          0       0        679
# 4                   0.00         0          0       1          6
#
#    num_followers  num_following  sim_name_username_Full match  \
# 0           1000            955                             0
# 1           2740            533                             0
# 2            159             98                             0
# 3            414            651                             0
# 4            151            126                             0
#
#    sim_name_username_No match  sim_name_username_Partial match
# 0                           1                                0
# 1                           0                                1
# 2                           0                                1
# 3                           0                                1
# 4                           1                                0

# %%
from sklearn.linear_model import LogisticRegression


features_train = df_train.iloc[:, 1:]
target_train = df_train.loc[:, 'fake']

model_log = LogisticRegression(solver='lbfgs', max_iter=1000, C=1e42, random_state=42)

model_log.fit(features_train, target_train)

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
features_train_scaled = scaler.fit_transform(features_train)

model_reg = LogisticRegression(solver='lbfgs', max_iter=1000, C=0.5, random_state=42)

model_reg.fit(features_train_scaled, target_train)
# Out:
# LogisticRegression(C=0.5, max_iter=1000, random_state=42)

# %%
df_test = pd.read_csv("social_media_test.csv",index_col=[0])
df_test = label_encoding(df_test)
df_test.head()
# Out:
#    fake profile_pic  ratio_numlen_username  len_fullname  \
# 0     0           1                   0.33             1
# 1     0           1                   0.00             5
# 2     0           1                   0.00             2
# 3     0           1                   0.00             1
# 4     0           1                   0.50             1
#
#    ratio_numlen_fullname  len_desc extern_url private  num_posts  \
# 0                   0.33        30          0       1         35
# 1                   0.00        64          0       1          3
# 2                   0.00        82          0       1        319
# 3                   0.00       143          0       1        273
# 4                   0.00        76          0       1          6
#
#    num_followers  num_following  sim_name_username_Full match  \
# 0         488.00            604                             1
# 1          35.00              6                             0
# 2         328.00            668                             0
# 3       14890.00           7369                             0
# 4         225.00            356                             0
#
#    sim_name_username_No match  sim_name_username_Partial match
# 0                           0                                0
# 1                           0                                1
# 2                           0                                1
# 3                           1                                0
# 4                           1                                0

# %%
features_test = df_test.drop('fake',axis=1)
target_test = df_test['fake']

target_test_pred_log = model_log.predict(features_test)

from sklearn.metrics import precision_score, recall_score
precision_log = precision_score(target_test, target_test_pred_log)
recall_log = recall_score(target_test, target_test_pred_log)

print('Precision of model without regularisation: ', precision_log)
print('Recall of model without regularisation: ', recall_log)
# Out:
# Precision of model without regularisation:  0.8666666666666667
# Recall of model without regularisation:  0.8666666666666667

# %%
features_test_scaled = scaler.transform(features_test)

target_test_pred_reg = model_reg.predict(features_test_scaled)

precision_reg = precision_score(target_test, target_test_pred_reg)
recall_reg = recall_score(target_test, target_test_pred_reg)

print('Precision of model with regularisation: ', precision_reg)
print('Recall of model with regularisation: ', recall_reg)
# Out:
# Precision of model with regularisation:  0.8813559322033898
# Recall of model with regularisation:  0.8666666666666667

# %%
from sklearn.metrics import roc_curve

def roc_curve_values(model,features,target):
    target_test_pred_proba = model.predict_proba(features)

    false_positive_rate, recall, threshold = roc_curve(target,
                                                       target_test_pred_proba[:,1],
                                                       drop_intermediate=False)

    return false_positive_rate, recall, target_test_pred_proba

# %%
false_positive_rate_log, recall_log, target_test_pred_proba_log  = roc_curve_values(model_log,features_test,target_test)

# %%
false_positive_rate_reg, recall_reg, target_test_pred_proba_reg  = roc_curve_values(model_reg,features_test,target_test)

# %%
def roc_curve_plot(false_positive_rate,recall,label):
    plt.style.use('fivethirtyeight')
    fig,ax=plt.subplots()

    ax.plot([0, 1], ls = "--", label='random model')
    ax.plot([0, 0], [1, 0], c=".7", ls='--', label='ideal model')
    ax.plot([1, 1], c=".7", ls='--')

    ax.plot(false_positive_rate,recall, label = label)

    ax.set_title("Receiver Operating Characteristic")
    ax.set_xlabel("False Positive Rate")
    ax.set_ylabel("Recall")
    ax.legend()

# %%
roc_curve_plot(false_positive_rate_log,recall_log,'model_log')

# %%
roc_curve_plot(false_positive_rate_reg,recall_reg,'model_reg')

# %%
from sklearn.metrics import roc_auc_score
print('roc_auc_score for model without regularization', roc_auc_score(target_test, target_test_pred_proba_log[:, 1]))
print('roc_auc_score for model with regularization', roc_auc_score(target_test, target_test_pred_proba_reg[:, 1]))
# Out:
# roc_auc_score for model without regularization 0.9636111111111111
# roc_auc_score for model with regularization 0.7763888888888889

# %%
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV

pipeline_log = Pipeline([('scaler',StandardScaler()),('classifier',LogisticRegression(solver='saga',
                                                                  max_iter=1000,
                                                                  random_state=42))])
C_values = np.geomspace(start=0.001, stop=1000, num=14)
search_space_grid = [{'classifier__penalty': ['l1', 'l2'],
                      'classifier__C': C_values}]

model_grid = GridSearchCV(estimator=pipeline_log,
                          param_grid=search_space_grid,
                          scoring='roc_auc',
                          cv=5,
                          n_jobs=-1)

model_grid.fit(features_train, target_train)

print(model_grid.best_estimator_)
print(model_grid.best_params_)
print(model_grid.best_score_)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('classifier',
#                  LogisticRegression(C=np.float64(4.923882631706742),
#                                     max_iter=1000, random_state=42,
#                                     solver='saga'))])
# {'classifier__C': np.float64(4.923882631706742), 'classifier__penalty': 'l2'}
# 0.9657175042242944

# %%
false_positive_rate_grid, recall_grid, target_test_pred_proba  = roc_curve_values(model_grid,features_test,target_test)
roc_curve_plot(false_positive_rate_grid,recall_grid,'model_grid')

# %%
target_test_pred_proba = model_grid.predict_proba(features_test)
roc_auc_score(target_test, target_test_pred_proba[:, 1])
# Out:
# np.float64(0.9391666666666667)

# %%
df_aim = pd.read_csv("social_media_aim.csv",index_col=[0])
df_aim = label_encoding(df_aim)
features_aim = df_aim.copy()

df_aim.loc[:, 'fake_pred_proba'] = model_grid.predict_proba(features_aim)[:, 1]
df_aim.loc[:, 'fake_pred'] = model_grid.predict(features_aim)
df_aim
# Out:
#   profile_pic  ratio_numlen_username  len_fullname  ratio_numlen_fullname  \
# 0           1                   0.33             1                   0.33
# 1           1                   0.22             2                   0.00
# 2           0                   0.00             2                   0.00
# 3           1                   0.33             1                   0.00
# 4           1                   0.00             1                   0.00
# 5           1                   0.27             1                   0.00
# 6           0                   0.44             1                   0.44
#
#    len_desc extern_url private  num_posts  num_followers  num_following  \
# 0        30          0       1         35         488.00            604
# 1        63          0       1         46         464.00            367
# 2         0          0       0          0          22.00             82
# 3         0          0       0         81          75.00             55
# 4       137          1       0       1065      155537.00           1395
# 5         0          0       0          0          45.00             64
# 6       112          0       0          4         415.00           1445
#
#    sim_name_username_Full match  sim_name_username_No match  \
# 0                             1                           0
# 1                             0                           0
# 2                             0                           1
# 3                             0                           0
# 4                             0                           1
# 5                             0                           0
# 6                             1                           0
#
#    sim_name_username_Partial match  fake_pred_proba  fake_pred
# 0                                0             1.00          1
# 1                                1             0.22          0
# 2                                0             0.98          1
# 3                                1             0.63          1
# 4                                0             0.00          0
# 5                                1             0.71          1
# 6                                0             1.00          1
